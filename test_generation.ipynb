# %% [markdown]
# # Test Catalogue Generation and Algorithms Comparison

# %%
import numpy as np
import pandas as pd
from obspy import read
from obspy.signal.trigger import classic_sta_lta, trigger_onset
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import os

from scipy import signal
from matplotlib import cm

import itertools
from sklearn.cluster import KMeans

# %%
# Path directory

def get_mseed_data(data_path):
   
    mseed_files = []

    if 'lunar' in data_path:
        categories = os.listdir(data_path)
        # Remove .DS_Store file if it exists
        if '.DS_Store' in categories:
            categories.remove('.DS_Store')

        for category in categories:
            path = data_path + category + '/'
            files = [f for f in os.listdir(path) if f.endswith('.mseed')]
            for f in files:
                mseed_files.append(path + f)
    
    else:
        files = [f for f in os.listdir(data_path) if f.endswith('.mseed')]
        for f in files:
            mseed_files.append(data_path + f)

    return mseed_files

moon_test_path = './data/lunar/test/data/'
mars_test_path = './data/mars/test/data/'
moon_data = get_mseed_data(moon_test_path)
mars_data = get_mseed_data(mars_test_path)

# %%
file = moon_data[0]

st = read(file)
tr = st.traces[0].copy()
tr_times = tr.times()
tr_data = tr.data

# %%
def plot_spectrogram(st, arrival=None):
    tr = st.traces[0]
    tr_times = tr.times()
    tr_data = tr.data

    f, t, sxx = signal.spectrogram(tr_data, tr.stats.sampling_rate)

    vmax = sxx.max()
    vmin = sxx.min()

    fig, (ax1, ax2) = plt.subplots(2,1,figsize=(10,10))

    ax1.plot(tr_times,tr_data)
    ax1.set_xlim([min(tr_times),max(tr_times)])
    ax1.set_ylabel('Velocity (m/s)')
    ax1.set_xlabel('Time (s)')
    ax1.set_title(f'{st[0]}', fontweight='bold')

    vals = ax2.pcolormesh(t, f, sxx, cmap=cm.jet, vmin=vmin, vmax=vmax)
    ax2.set_xlim([min(tr_times),max(tr_times)])
    ax2.set_xlabel(f'Time (Day Hour:Minute)', fontweight='bold')
    ax2.set_ylabel('Frequency (Hz)', fontweight='bold')
    
    if arrival is not None:
        ax1.axvline(x = arrival, color='red',label='Rel. Arrival')
        ax2.axvline(x=arrival, c='red')

    cbar = plt.colorbar(vals, orientation='horizontal')
    cbar.set_label('Power ((m/s)^2/sqrt(Hz))', fontweight='bold')

    plt.show()

file1 = moon_data[0]
st1 = read(file1)

plot_spectrogram(st1)

# %%
def sta_lta(st, sta, lta):
    tr = st.traces[0]
    df = tr.stats.sampling_rate

    cft = classic_sta_lta(tr.data, int(sta * df), int(lta * df))

    return cft

def plot_sta_lta(st, sta, lta, arrival=None):

    ctf = sta_lta(st, sta, lta)
    tr_times = st.traces[0].times()

    fig, ax = plt.subplots(1,1,figsize=(10,5))
    ax.plot(tr_times, ctf)
    ax.set_xlim([min(tr_times),max(tr_times)])
    ax.set_xlabel('Time (s)', fontweight='bold')
    ax.set_ylabel('STA/LTA Ratio', fontweight='bold')
    ax.set_title('STA/LTA Ratio', fontweight='bold')

    if arrival is not None:
        ax.axvline(x = arrival, color='red',label='Rel. Arrival')

    plt.show()

sta = 500
lta = 10000

st1.plot()

plot_sta_lta(st1, sta, lta)

# %%
st_filt = st1.copy()
st_filt.filter('bandpass', freqmin=0.8, freqmax=1)

plot_spectrogram(st_filt)

plot_sta_lta(st_filt, sta, lta)

# %% [markdown]
# ## K-Means Clustering (Vento idea)

# %%
def find_clusters(hf_points, _min_dist = 2000):

    X = np.array(hf_points).reshape(-1, 1)  

    initial_n_clusters = 3 
    kmeans = KMeans(n_clusters=initial_n_clusters)
    kmeans.fit(X)

    centers = kmeans.cluster_centers_

    def filter_centroids(centroids, min_distance):
        filtered_centroids = []
        
        for centroid in centroids:
            if all(np.linalg.norm(centroid - other) >= min_distance for other in filtered_centroids):
                filtered_centroids.append(centroid)
        
        return np.array(filtered_centroids)

    filtered_centroids = filter_centroids(centers, _min_dist)

    return filtered_centroids



def seismic_centers_detect(st, _target=None, _STA=120, _LTA=600, _high_freq_thresh=0.05, _power_thresh=0.4, display=True):
    

    tr = st.traces[0]
    tr_times = tr.times()
    tr_data = tr.data
    tr_sampling_rate = tr.stats.sampling_rate

    act_quake_cat = _target

    fp, t, sxx = signal.spectrogram(tr_data, tr_sampling_rate, nperseg=256, noverlap=128, scaling='density')
    vmax = sxx.max()
    vmin = sxx.min()

    # Sampling frequency of our trace
    df = tr_sampling_rate

    sta_len = _STA
    lta_len = _LTA

    cft = classic_sta_lta(tr_data, int(sta_len * df), int(lta_len * df))


    if display:
        # Plot characteristic function
        fig, (ax, ax1 ,ax2) = plt.subplots(3, 1, figsize=(12, 8))

        ax.plot(tr_times,tr_data)
        ax.set_xlim([min(tr_times),max(tr_times)])
        ax.set_ylabel('Velocity (m/s)')

        ax.set_title('Filtered')

        # Plot characteristic function
        ax1.plot(tr_times, cft)
        ax1.set_xlim([min(tr_times), max(tr_times)])
        ax1.set_ylabel('Characteristic function')
        
        #ax1.legend()

        ## Plot spectrogram
        vals = ax2.pcolormesh(t, fp, sxx, cmap=cm.jet, vmin = vmin, vmax=vmax)

        ax2.set_xlim([min(tr_times), max(tr_times)])
        ax2.set_xlabel(f'Time (s)', fontweight='bold')
        ax2.set_ylabel('Frequency (Hz)')
        
        if _target:
            ax.axvline(x=act_quake_cat, c='red')
            ax1.axvline(x=act_quake_cat, c='red')
            ax2.axvline(x=act_quake_cat, c='red', linewidth=1)


    # Normalize fp and sxx
    fp = (fp - np.min(fp)) / (np.max(fp) - np.min(fp))
    sxx = (sxx - np.min(sxx)) / (np.max(sxx) - np.min(sxx))  

    high_freq_mask = fp >= _high_freq_thresh  # Mask for high frequencies
    high_power_mask = sxx > _power_thresh    # Mask for sections with high power
    # Combined mask for high-frequency and high-power regions
    combined_mask = np.logical_and(high_freq_mask[:, None], high_power_mask)
    # Extract high-frequency sections
    high_freq_sections = []
    for i in range(sxx.shape[1]):  # Iterate over time steps
        high_freqs_at_t = fp[combined_mask[:, i]]  # Extract frequencies for time step i
        if len(high_freqs_at_t) > 0:
            high_freq_sections.append((t[i], high_freqs_at_t))

    if len(high_freq_sections) > 0:
        hf_points = [row[0] for row in high_freq_sections]
        centers = find_clusters(hf_points)
        swd_centers = list(itertools.chain.from_iterable(centers))

        if display:
            for v in swd_centers:
                ax2.axvline(x=v, c='yellow', linewidth=1)
                ax.axvline(x=v-2500, c='blue', linewidth=4)
                ax.axvline(x=min((v+6500),(tr_times[-1]-100)), c='blue', linewidth=4)

    return swd_centers

swd_centers = seismic_centers_detect(st_filt, _target=None, _STA=120, _LTA=600, _high_freq_thresh=0.05, _power_thresh=0.4, display=False)

swd_centers
# Out:
# [np.float64(17259.87421383648)]

# %%
def get_df_from_data(data_path, algo='centers', sta=120, lta=600, thr_on=5, thr_off=0.5):
    
    name = data_path.split('/')[2]
    mseed_files = get_mseed_data(data_path)

    fnames = []
    detections = []
    triggers = []

    for elem in mseed_files:
        st = read(elem)
        st_filt = st.copy()
        st_filt.filter('bandpass', freqmin=0.9, freqmax=1.2)
        print(f'Processing {elem}...')

        fname = elem.split('/')[-1].replace('.mseed', '')
        starttime = st[0].stats.starttime

        if algo == 'centers':
            try:
                swd_centers = seismic_centers_detect(st_filt, _target=None, _STA=sta, _LTA=lta, _high_freq_thresh=0.05, _power_thresh=0.4, display=False)

                for i in range(len(swd_centers)):
                    on_time = starttime + timedelta(seconds=swd_centers[i])
                    fnames.append(fname)
                    detections.append(on_time)
                    triggers.append(swd_centers[i])
            except:
                print(f'Error processing {elem}...')
                continue
        
        # elif algo == 'sta_lta':

        #     tr_data = st_filt[0].data

        #     df = st_filt[0].stats.sampling_rate
        #     ctf = classic_sta_lta(tr_data, int(sta*df), int(lta*df))
        #     on_off = np.array(trigger_onset(ctf, thr_on, thr_off))

        #     for i in np.arange(0,len(on_off)):
        #         triggers_ = on_off[i]
        #         on_time = starttime + timedelta(seconds = tr_times[triggers_[0]])
        #         detections.append(on_time)
        #         fnames.append(fname)
        #         triggers.append(triggers_[0])

    print('Done!')
    print(f'fnames: {len(fnames)}')
    print(f'detections: {len(detections)}')
    print(f'triggers: {len(triggers)}')

    df = pd.DataFrame({'filename': fnames, 'time_abs(%Y-%m-%dT%H:%M:%S.%f': detections, 'time_rel(sec)': triggers})
    df.to_csv(f'detections_{name}_{algo}.csv', index=False)

    return df

# %%
## Centers_method algorithm

# Path directory
moon_test_path = './data/lunar/test/data/'
mars_test_path = './data/mars/test/data/'

# Create dataframes
moon_df = get_df_from_data(moon_test_path)
mars_df = get_df_from_data(mars_test_path)
# Out:
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-10-26HR00_evid00133.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1974-10-02HR00_evid00572.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-11-19HR00_evid00335.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-03-14HR00_evid00018.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1974-03-14HR00_evid00506.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-10-06HR00_evid00125.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1973-04-23HR00_evid00399.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-01-03HR00_evid00057.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-06-11HR00_evid00096.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-02-28HR00_evid00192.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-05-24HR00_evid00028.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1969-12-16HR00_evid00006.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-11-03HR00_evid00050.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-03-15HR00_evid00073.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1974-03-30HR00_evid00512.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1975-04-21HR00_evid00638.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-10-06HR00_evid00124.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-09-09HR00_evid00043.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1975-05-16HR00_evid00651.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-11-14HR00_evid00331.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-11-24HR00_evid00156.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-04-03HR00_evid00021.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-01-09HR00_evid00007.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1974-05-09HR00_evid00522.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-07-20HR00_evid00037.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-02-21HR00_evid00190.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-06-27HR00_evid00101.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-12-15HR00_evid00349.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1973-10-03HR03_evid00461.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-05-15HR00_evid00223.mseed...
# Error processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-05-15HR00_evid00223.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-05-25HR00_evid00029.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-11-03HR00_evid00051.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-05-19HR00_evid00228.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1973-10-10HR00_evid00463.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-06-19HR00_evid00031.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-07-18HR00_evid00036.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1975-06-15HR00_evid00660.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1977-04-26HR00_evid00924.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1977-07-19HR00_evid00991.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1975-06-17HR00_evid00662.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1977-04-11HR00_evid00915.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1973-11-22HR00_evid00475.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-12-06HR00_evid00342.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1974-07-25HR05_evid00553.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-05-23HR00_evid00027.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-07-27HR00_evid00039.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-07-17HR00_evid00035.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1973-08-08HR00_evid00437.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-01-17HR00_evid00060.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1977-09-13HR00_evid01012.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-04-08HR01_evid00083.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-01-05HR00_evid00059.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1973-03-12HR00_evid00384.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1974-06-30HR00_evid00543.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-12-02HR00_evid00341.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1975-05-20HR00_evid00652.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-10-26HR00_evid00049.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1972-01-26HR00_evid00186.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-02-07HR00_evid00014.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-05-20HR00_evid00026.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1977-04-24HR00_evid00923.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1971-05-22HR00_evid00092.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-02-18HR00_evid00016.mseed...
# Processing ./data/lunar/test/data/S12_GradeB/xa.s12.00.mhz.1970-03-30HR00_evid00020.mseed...
# Processing ./data/lunar/test/data/S16_GradeB/xa.s16.00.mhz.1973-08-25HR00_evid00443.mseed...
# Processing ./data/lunar/test/data/S16_GradeB/xa.s16.00.mhz.1973-12-18HR00_evid00487.mseed...
# Processing ./data/lunar/test/data/S16_GradeB/xa.s16.00.mhz.1974-11-14HR00_evid00587.mseed...
# Processing ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1973-10-27HR00_evid00134.mseed...
# Processing ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1975-06-22HR00_evid00194.mseed...
# Processing ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1974-11-17HR00_evid00162.mseed...
# Processing ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1974-10-19HR00_evid00157.mseed...
# Processing ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1973-08-10HR00_evid00126.mseed...
# Processing ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1973-04-04HR00_evid00098.mseed...
# Processing ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1974-11-21HR00_evid00166.mseed...
# Processing ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1975-04-12HR00_evid00190.mseed...
# Processing ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1974-12-15HR00_evid00169.mseed...
# Processing ./data/lunar/test/data/S15_GradeA/xa.s15.00.mhz.1974-12-15HR00_evid00170.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1973-07-31HR00_evid00123.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1974-12-25HR00_evid00174.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1974-12-12HR02_evid00168.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1974-11-11HR00_evid00160.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1975-02-19HR00_evid00180.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1972-09-10HR00_evid00075.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1972-11-08HR00_evid00080.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1977-06-02HR00_evid00255.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1975-03-26HR00_evid00186.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1974-05-19HR00_evid00146.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1972-11-14HR00_evid00081.mseed...
# Error processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1972-11-14HR00_evid00081.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1977-04-17HR00_evid00249.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1974-12-15HR00_evid00172.mseed...
# Processing ./data/lunar/test/data/S16_GradeA/xa.s16.00.mhz.1972-11-06HR00_evid00079.mseed...
# Processing ./data/lunar/test/data/S15_GradeB/xa.s15.00.mhz.1975-05-20HR00_evid00653.mseed...
# Processing ./data/lunar/test/data/S15_GradeB/xa.s15.00.mhz.1974-08-04HR00_evid00557.mseed...
# Processing ./data/lunar/test/data/S15_GradeB/xa.s15.00.mhz.1974-06-30HR00_evid00542.mseed...
# Processing ./data/lunar/test/data/S15_GradeB/xa.s15.00.mhz.1974-02-06HR00_evid00497.mseed...
# Processing ./data/lunar/test/data/S15_GradeB/xa.s15.00.mhz.1974-06-16HR00_evid00536.mseed...
# Done!
# fnames: 116
# detections: 116
# triggers: 116
# Processing ./data/mars/test/data/XB.ELYSE.02.BHV.2021-05-02HR01_evid0017.mseed...
# Processing ./data/mars/test/data/XB.ELYSE.02.BHV.2019-07-26HR12_evid0033.mseed...
# Processing ./data/mars/test/data/XB.ELYSE.02.BHV.2021-10-11HR23_evid0011.mseed...
# Processing ./data/mars/test/data/XB.ELYSE.02.BHV.2022-04-09HR22_evid0002.mseed...
# Processing ./data/mars/test/data/XB.ELYSE.02.BHV.2019-07-26HR12_evid0034.mseed...
# Processing ./data/mars/test/data/XB.ELYSE.02.BHV.2019-05-23HR02_evid0041.mseed...
# Processing ./data/mars/test/data/XB.ELYSE.02.BHV.2022-05-04HR23_evid0001.mseed...
# Processing ./data/mars/test/data/XB.ELYSE.02.BHV.2021-12-24HR22_evid0007.mseed...
# Processing ./data/mars/test/data/XB.ELYSE.02.BHV.2019-09-21HR03_evid0032.mseed...
# Done!
# fnames: 14
# detections: 14
# triggers: 14

# %%
moon_df.head()
# Out:
#                                  filename time_abs(%Y-%m-%dT%H:%M:%S.%f  \
# 0  xa.s12.00.mhz.1971-10-26HR00_evid00133   1971-10-26T04:48:02.997094Z
# 1  xa.s12.00.mhz.1974-10-02HR00_evid00572   1974-10-02T13:40:48.873774Z
# 2  xa.s12.00.mhz.1972-11-19HR00_evid00335   1972-11-19T18:34:57.409154Z
# 3  xa.s12.00.mhz.1970-03-14HR00_evid00018   1970-03-14T20:11:01.356612Z
# 4  xa.s12.00.mhz.1970-03-14HR00_evid00018   1970-03-14T03:22:45.640000Z
#
#    time_rel(sec)
# 0   17282.415094
# 1   49248.603774
# 2   66896.733154
# 3   72660.836612
# 4   12165.120000

# %% [markdown]
# ## STA / LTA algo

# %%
# Path directory
moon_test_path = './data/lunar/test/data/'
mars_test_path = './data/mars/test/data/'

sta = 100
lta = 20000

thr_on = 10
thr_off = 0.5

def get_file_from_name(name, data_path):
    mseed_files = get_mseed_data(data_path)
    for f in mseed_files:
        if name in f:
            return f

    return None

def get_df_from_data_stalta(data_path, sta, lta, thr_on, thr_off):
    # create dataframe
    df = pd.DataFrame(columns=['filename', 'time_abs', 'time_rel(sec)'])
    name_data = data_path.split('/')[2]

    for i in range(0, len(moon_data)):
        file_path = moon_data[i]
        name = file_path.split('/')[-1].replace('.mseed', '')

        st = read(file_path)
        st_filt = st.copy()
        st_filt.filter('bandpass', freqmin=0.8, freqmax=1)

        tr_data = st_filt[0].data
        tr_times = st_filt[0].times()

        ts = st_filt[0].stats.sampling_rate
        ctf = classic_sta_lta(tr_data, int(sta*ts), int(lta*ts))
        on_off = np.array(trigger_onset(ctf, thr_on, thr_off))

        for j in np.arange(0, len(on_off)):
            triggers_ = on_off[j]
            on_time = st[0].stats.starttime + timedelta(seconds=tr_times[triggers_[0]])
            df.loc[len(df)] = {
                'filename': name,
                'time_abs': on_time.strftime('%Y-%m-%dT%H:%M:%S.%f'),
                'time_rel(sec)': tr_times[triggers_[0]]
            }
    df.to_csv(f'detections_{name_data}_sta_lta.csv', index=False)

    return df

# Create dataframe
moon_df = get_df_from_data_stalta(moon_test_path, sta, lta, thr_on, thr_off)

# %%
# load and test dataframe
detections = pd.read_csv('detections_moon_sta_lta.csv')

for i in range(10, 20):
    name = detections['filename'][i]
    time = detections['time_rel(sec)'][i]
    file = get_file_from_name(name, moon_test_path)
    st = read(file)
    st_filt = st.copy()
    st_filt.filter('bandpass', freqmin=0.8, freqmax=1)
    tr_times = st_filt[0].times()
    tr_data = st_filt[0].data
    ts = st_filt[0].stats.sampling_rate

    cft = classic_sta_lta(tr_data, int(sta * ts), int(lta * ts))

    # Plot characteristic function
    fig,ax = plt.subplots(1,1,figsize=(12,3))
    ax.plot(tr_times,cft)
    ax.set_xlim([min(tr_times),max(tr_times)])
    ax.axvline(x=time, color='red',label='Rel. Arrival')
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Characteristic function')

# %% [markdown]
# # Comparison Algos

# %%
# comparison between centers and sta_lta methods

import random

# Load dataframes
centers_moon = pd.read_csv('detections_lunar_centers.csv')
sta_lta_moon = pd.read_csv('detections_lunar_sta_lta.csv')

for i in np.random.randint(0, len(centers_moon), 10):
    filename = centers_moon.loc[i]['filename']
    
    try: 
        time_centers = centers_moon.loc[i]['time_rel(sec)']
        time_sta_lta = sta_lta_moon[sta_lta_moon['filename'] == filename]['time_rel(sec)'].values[0]
    except:
        continue

    file = get_file_from_name(filename, moon_test_path)
    st = read(file)
    st_filt = st.copy()
    st_filt.filter('bandpass', freqmin=0.8, freqmax=1)
    tr_times = st_filt[0].times()
    tr_data = st_filt[0].data
    ts = st_filt[0].stats.sampling_rate

    fig, ax = plt.subplots(1,1,figsize=(12,3))
    ax.plot(tr_times,tr_data)
    ax.set_xlim([min(tr_times),max(tr_times)])
    ax.axvline(x=time_centers, color='red',label='Centers')
    ax.axvline(x=time_sta_lta, color='blue',label='STA/LTA')
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Velocity (m/s)')
    ax.legend()
